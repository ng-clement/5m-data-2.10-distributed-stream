# %% [markdown]
# # Hands-on with Spark (Structured Streaming)
#
# ![spark](https://cdn-images-1.medium.com/max/300/1*c8CtvqKJDVUnMoPGujF5fA.png)
#
# In the previous lesson, we learnt about Spark SQL, Dataframes and Pandas API. In this lesson, we will continue with the Structured Streaming.
#
# Structured Streaming is a scalable and fault-tolerant stream processing engine built on the Spark SQL engine. You can express your streaming computation the same way you would express a batch computation on static data. The Spark SQL engine will take care of running it incrementally and continuously and updating the final result as streaming data continues to arrive.
#
# You can use the Dataset/DataFrame API to express streaming aggregations, event-time windows, stream-to-batch joins, etc. The computation is executed on the same optimized Spark SQL engine. Finally, the system ensures end-to-end exactly-once fault-tolerance guarantees through checkpointing and Write-Ahead Logs. In short, Structured Streaming provides **fast, scalable, fault-tolerant, end-to-end exactly-once** stream processing without the user having to reason about streaming.
#
# Internally, by default, Structured Streaming queries are processed using a micro-batch processing engine, which processes data streams as a series of small batch jobs thereby achieving end-to-end latencies as low as 100 milliseconds and exactly-once fault-tolerance guarantees.

# %% [markdown]
# ## Installing and Initializing Spark
#
# First, like previously, we'll need to install Spark and its dependencies:
#
# 1.   Java 8
# 2.   Apache Spark with Hadoop
# 3.   Findspark (used to locate the Spark in the system)

# %%
import os
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.4 pyspark-shell'

# set the options to connect to our Kafka cluster
options = {
    # "kafka.sasl.jaas.config": 'org.apache.kafka.common.security.scram.ScramLoginModule required username="YnJhdmUtZmlzaC0xMTQ2MyQSvwXBuLOQsV1W7YffuC8cDaZcA3fKQwakMhnQGgg" password="MDUxNjc4YzEtYzYxNy00NTE1LWEwNWYtMDBhODRlZmE0OGJm";',
    # "kafka.sasl.mechanism": "SCRAM-SHA-256",
    # "kafka.security.protocol" : "SASL_SSL",
    "kafka.bootstrap.servers": 'localhost:9092',
    "subscribe": 'pizza-orders',
}

# %%
# # findspark is only required if you are using a standalone Spark installation (downloaded tar.gz)
# import findspark
# findspark.init()

# %% [markdown]
# The below cell may take a few minutes to run. It is slow because:
# - Package downloading: Your PYSPARK_SUBMIT_ARGS includes a Kafka package that needs to be downloaded from Maven repositories on first run
# - JVM cold start: Initial JVM startup is always slow
# - Jupyter overhead: Running in a notebook adds some initialization overhead

# %%
# We will only use 2 cores below to speed up creation of the spark session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("LearnSparkStreaming").master("local[2]").getOrCreate()
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 26/06/05 11:18:22 WARN Utils: Your hostname, Zero resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/06/05 11:18:22 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/clement/miniconda3/envs/kafka/lib/python3.11/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/clement/.ivy2/cache
# The jars for the packages stored in: /home/clement/.ivy2/jars
# org.apache.spark#spark-sql-kafka-0-10_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-be08ba3e-c47e-44a8-865e-1a34ff785cad;1.0
# 	confs: [default]
# 	found org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.4 in central
# 	found org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.4 in central
# 	found org.apache.kafka#kafka-clients;3.4.1 in central
# 	found org.lz4#lz4-java;1.8.0 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.5 in central
# 	found org.slf4j#slf4j-api;2.0.7 in central
# 	found org.apache.hadoop#hadoop-client-runtime;3.3.4 in central
# 	found org.apache.hadoop#hadoop-client-api;3.3.4 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found com.google.code.findbugs#jsr305;3.0.0 in central
# 	found org.apache.commons#commons-pool2;2.11.1 in central
# downloading https://repo1.maven.org/maven2/org/apache/spark/spark-sql-kafka-0-10_2.12/3.5.4/spark-sql-kafka-0-10_2.12-3.5.4.jar ...
# 	[SUCCESSFUL ] org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.4!spark-sql-kafka-0-10_2.12.jar (130ms)
# downloading https://repo1.maven.org/maven2/org/apache/spark/spark-token-provider-kafka-0-10_2.12/3.5.4/spark-token-provider-kafka-0-10_2.12-3.5.4.jar ...
# 	[SUCCESSFUL ] org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.4!spark-token-provider-kafka-0-10_2.12.jar (62ms)
# downloading https://repo1.maven.org/maven2/org/apache/kafka/kafka-clients/3.4.1/kafka-clients-3.4.1.jar ...
# 	[SUCCESSFUL ] org.apache.kafka#kafka-clients;3.4.1!kafka-clients.jar (385ms)
# downloading https://repo1.maven.org/maven2/com/google/code/findbugs/jsr305/3.0.0/jsr305-3.0.0.jar ...
# 	[SUCCESSFUL ] com.google.code.findbugs#jsr305;3.0.0!jsr305.jar (53ms)
# downloading https://repo1.maven.org/maven2/org/apache/commons/commons-pool2/2.11.1/commons-pool2-2.11.1.jar ...
# 	[SUCCESSFUL ] org.apache.commons#commons-pool2;2.11.1!commons-pool2.jar (79ms)
# downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-client-runtime/3.3.4/hadoop-client-runtime-3.3.4.jar ...
# 	[SUCCESSFUL ] org.apache.hadoop#hadoop-client-runtime;3.3.4!hadoop-client-runtime.jar (1373ms)
# downloading https://repo1.maven.org/maven2/org/lz4/lz4-java/1.8.0/lz4-java-1.8.0.jar ...
# 	[SUCCESSFUL ] org.lz4#lz4-java;1.8.0!lz4-java.jar (78ms)
# downloading https://repo1.maven.org/maven2/org/xerial/snappy/snappy-java/1.1.10.5/snappy-java-1.1.10.5.jar ...
# 	[SUCCESSFUL ] org.xerial.snappy#snappy-java;1.1.10.5!snappy-java.jar(bundle) (232ms)
# downloading https://repo1.maven.org/maven2/org/slf4j/slf4j-api/2.0.7/slf4j-api-2.0.7.jar ...
# 	[SUCCESSFUL ] org.slf4j#slf4j-api;2.0.7!slf4j-api.jar (66ms)
# downloading https://repo1.maven.org/maven2/org/apache/hadoop/hadoop-client-api/3.3.4/hadoop-client-api-3.3.4.jar ...
# 	[SUCCESSFUL ] org.apache.hadoop#hadoop-client-api;3.3.4!hadoop-client-api.jar (980ms)
# downloading https://repo1.maven.org/maven2/commons-logging/commons-logging/1.1.3/commons-logging-1.1.3.jar ...
# 	[SUCCESSFUL ] commons-logging#commons-logging;1.1.3!commons-logging.jar (57ms)
# :: resolution report :: resolve 5899ms :: artifacts dl 3534ms
# 	:: modules in use:
# 	com.google.code.findbugs#jsr305;3.0.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	org.apache.commons#commons-pool2;2.11.1 from central in [default]
# 	org.apache.hadoop#hadoop-client-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client-runtime;3.3.4 from central in [default]
# 	org.apache.kafka#kafka-clients;3.4.1 from central in [default]
# 	org.apache.spark#spark-sql-kafka-0-10_2.12;3.5.4 from central in [default]
# 	org.apache.spark#spark-token-provider-kafka-0-10_2.12;3.5.4 from central in [default]
# 	org.lz4#lz4-java;1.8.0 from central in [default]
# 	org.slf4j#slf4j-api;2.0.7 from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.5 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   11  |   11  |   11  |   0   ||   11  |   11  |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-be08ba3e-c47e-44a8-865e-1a34ff785cad
# 	confs: [default]
# 	11 artifacts copied, 0 already retrieved (57002kB/329ms)
# 26/06/05 11:18:33 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.255.255.254:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>LearnSparkStreaming</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Read and Analyze Kafka stream in "Batch" Mode
#
# Let's start with reading and analyzing our `pizza-orders` kafka topic in the usual "batch" mode of Spark SQL and Dataframes. This is akin to the batch queries we did in the previous lesson. In this case we are taking the messages with the earliest to latest offsets of the topic as a single "batch".

# %%
pizza_df = spark.read.format('kafka')\
    .options(**options)\
    .load()

# %%
pizza_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
pizza_df.show()
# Out:
# 26/06/05 11:19:23 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 0:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+------------+---------+------+--------------------+-------------+
# |                 key|               value|       topic|partition|offset|           timestamp|timestampType|
# +--------------------+--------------------+------------+---------+------+--------------------+-------------+
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     0|2026-06-05 10:55:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     1|2026-06-05 10:55:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     2|2026-06-05 10:55:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     3|2026-06-05 10:55:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     4|2026-06-05 10:55:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     5|2026-06-05 11:01:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     6|2026-06-05 11:01:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     7|2026-06-05 11:01:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     8|2026-06-05 11:01:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|     9|2026-06-05 11:01:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    10|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    11|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    12|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    13|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    14|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    15|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    16|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    17|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    18|2026-06-05 11:06:...|            0|
# |[7B 22 73 68 6F 7...|[7B 22 69 64 22 3...|pizza-orders|        0|    19|2026-06-05 11:06:...|            0|
# +--------------------+--------------------+------------+---------+------+--------------------+-------------+
# only showing top 20 rows

# %%
pizza_df.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)").show()
# Out:
# 26/06/05 11:20:08 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 1:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+
# |                 key|               value|
# +--------------------+--------------------+
# |{"shop": "Marios ...|{"id": 0, "shop":...|
# |{"shop": "Luigis ...|{"id": 1, "shop":...|
# |{"shop": "Mammami...|{"id": 2, "shop":...|
# |{"shop": "Ill Mak...|{"id": 3, "shop":...|
# |{"shop": "Circula...|{"id": 4, "shop":...|
# |{"shop": "Marios ...|{"id": 0, "shop":...|
# |{"shop": "Luigis ...|{"id": 1, "shop":...|
# |{"shop": "Its-a m...|{"id": 2, "shop":...|
# |{"shop": "Mammami...|{"id": 3, "shop":...|
# |{"shop": "Mammami...|{"id": 4, "shop":...|
# |{"shop": "Ill Mak...|{"id": 0, "shop":...|
# |{"shop": "Its-a m...|{"id": 1, "shop":...|
# |{"shop": "Mammami...|{"id": 2, "shop":...|
# |{"shop": "Luigis ...|{"id": 3, "shop":...|
# |{"shop": "Ill Mak...|{"id": 4, "shop":...|
# |{"shop": "Circula...|{"id": 0, "shop":...|
# |{"shop": "Circula...|{"id": 1, "shop":...|
# |{"shop": "Its-a m...|{"id": 2, "shop":...|
# |{"shop": "Its-a m...|{"id": 3, "shop":...|
# |{"shop": "Its-a m...|{"id": 4, "shop":...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StringType, IntegerType, LongType, DoubleType, StructType, ArrayType, StructField

# %%
pizza_schema = StructType([
  StructField("pizzaName", StringType()),
  StructField("additionalToppings", ArrayType(StringType())),
])

order_schema = StructType([
  StructField("address", StringType()),
  StructField("id", IntegerType()),
  StructField("name", StringType()),
  StructField("phoneNumber", StringType()),
  StructField("shop", StringType()),
  StructField("cost", DoubleType()),
  StructField("pizzas", ArrayType(pizza_schema)),
  StructField("timestamp", LongType()),
])

# %%
parsed_df = pizza_df.select("timestamp", from_json(col("value").cast("string"), order_schema).alias("value"))

# %%
parsed_df.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- value: struct (nullable = true)
#  |    |-- address: string (nullable = true)
#  |    |-- id: integer (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- phoneNumber: string (nullable = true)
#  |    |-- shop: string (nullable = true)
#  |    |-- cost: double (nullable = true)
#  |    |-- pizzas: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- pizzaName: string (nullable = true)
#  |    |    |    |-- additionalToppings: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- timestamp: long (nullable = true)

# %%
parsed_df.show(truncate=False)
# Out:
# 26/06/05 11:22:44 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 2:>                                                          (0 + 1) / 1]
# +-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |timestamp              |value                                                                                                                                                                                                                                                                                                                                            |
# +-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2026-06-05 10:55:21.139|{21087 Calvin Plains\nJonesland, NY 76392, 0, Jessica Smith, 001-701-915-3000, Marios Pizza, 18.47, [{Salami, [🫒 olives, 🍅 tomato, 🫒 olives]}, {Diavola, [🧀 blue cheese, 🫒 olives, 🫑 green peppers]}, {Margherita, []}], 1780628121116}                                                                                                    |
# |2026-06-05 10:55:23.141|{19721 Drew Key\nNew Donaldport, NH 05690, 1, Roger Brown, 475-943-3780x8105, Luigis Pizza, 11.26, [{Marinara, []}], 1780628123141}                                                                                                                                                                                                              |
# |2026-06-05 10:55:24.144|{278 Phillips Crossing Apt. 661\nPort Maryfurt, GU 86535, 2, Matthew Williams, 924-927-0965x759, Mammamia Pizza, 32.18, [{Margherita, [🍍 pineapple, 🍅 tomato, 🍅 tomato]}, {Mari & Monti, []}, {Peperoni, []}, {Marinara, []}], 1780628124143}                                                                                                 |
# |2026-06-05 10:55:25.24 |{547 Brenda Walks\nLake Ronaldborough, CT 52490, 3, Corey Rodriguez, 001-629-242-5711x630, Ill Make You a Pizza You Cant Refuse, 16.81, [{Diavola, [🌶️ hot pepper]}, {Peperoni, [🍅 tomato, 🫑 green peppers]}, {Marinara, [🥓 bacon]}, {Margherita, [🍓 strawberry, 🍓 strawberry, 🍍 pineapple]}, {Peperoni, [🍓 strawberry]}], 1780628125239}|
# |2026-06-05 10:55:26.243|{752 Brandon Expressway Apt. 815\nNorth Elizabeth, AR 84161, 4, Stephen Stevens, 253.786.2934, Circular Pi Pizzeria, 6.67, [{Marinara, []}], 1780628126243}                                                                                                                                                                                      |
# |2026-06-05 11:01:28.939|{144 Ross Port\nAliciafurt, KY 28535, 0, Ricky Sexton, 8667536484, Marios Pizza, 29.18, [{Peperoni, []}], 1780628488938}                                                                                                                                                                                                                         |
# |2026-06-05 11:01:30.943|{49595 Gary Port Suite 707\nNorth Michaelfort, CA 18853, 1, Russell Sanders, (873)972-6401x764, Luigis Pizza, 13.28, [{Peperoni, []}, {Mari & Monti, []}], 1780628490942}                                                                                                                                                                        |
# |2026-06-05 11:01:31.945|{4189 Madison Glens Suite 206\nLake Vickiborough, TN 20792, 2, Stephanie Rivera, (544)795-9493x841, Its-a me! Mario Pizza!, 46.88, [{Mari & Monti, [🌶️ hot pepper, 🥓 bacon]}], 1780628491944}                                                                                                                                                  |
# |2026-06-05 11:01:32.947|{77289 Dustin Villages\nLake Frank, NY 99386, 3, Kelli Hamilton DDS, 244-779-3581, Mammamia Pizza, 1.42, [{Margherita, [🧀 blue cheese, 🫒 olives]}, {Salami, [🧀 blue cheese, 🍌 banana, 🍍 pineapple]}, {Peperoni, [🥓 bacon, 🥓 bacon, 🧄 garlic]}, {Marinara, [🫒 olives, 🫒 olives, 🥓 bacon]}], 1780628492947}                             |
# |2026-06-05 11:01:33.949|{8697 Anthony Valley\nPort Kellymouth, FL 64221, 4, Patricia Castaneda, 328-798-9970x51560, Mammamia Pizza, 34.51, [{Peperoni, []}, {Mari & Monti, [🥚 egg, 🧅 onion]}, {Margherita, [🍌 banana]}], 1780628493949}                                                                                                                               |
# |2026-06-05 11:06:17.512|{409 Ward Stream\nKeithchester, WI 48718, 0, Marilyn Steele, 5594562103, Ill Make You a Pizza You Cant Refuse, 0.29, [{Mari & Monti, [🌶️ hot pepper, 🧄 garlic]}, {Diavola, [🧀 blue cheese, 🍌 banana]}], 1780628777512}                                                                                                                       |
# |2026-06-05 11:06:18.516|{272 Tammy Plains Suite 337\nMaryburgh, MI 97726, 1, Adam Edwards, 718-690-3899x582, Its-a me! Mario Pizza!, 13.19, [{Margherita, []}, {Salami, [🍅 tomato, 🥚 egg]}, {Peperoni, [🌶️ hot pepper, 🫑 green peppers]}, {Salami, []}], 1780628778515}                                                                                              |
# |2026-06-05 11:06:20.518|{3156 Dawson Knoll\nKelleyborough, PA 62488, 2, Sarah Moreno, 001-399-977-8759x18692, Mammamia Pizza, 7.28, [{Mari & Monti, [🫑 green peppers, 🫒 olives]}], 1780628780518}                                                                                                                                                                      |
# |2026-06-05 11:06:21.521|{0259 Brandon Valley\nRogermouth, ME 78143, 3, Megan Owens, 881.687.1132x952, Luigis Pizza, 18.75, [{Margherita, [🍅 tomato, 🫒 olives]}, {Marinara, [🌶️ hot pepper, 🧀 blue cheese]}], 1780628781521}                                                                                                                                          |
# |2026-06-05 11:06:22.522|{797 Shaw Junction\nLisachester, MO 34535, 4, Michelle Orr, (566)404-9945, Ill Make You a Pizza You Cant Refuse, 14.4, [{Salami, [🌶️ hot pepper, 🥚 egg, 🍓 strawberry]}, {Peperoni, [🍍 pineapple]}, {Peperoni, [🍅 tomato, 🍌 banana, 🫒 olives]}, {Peperoni, [🧄 garlic]}, {Diavola, [🥚 egg, 🫒 olives, 🍌 banana]}], 1780628782522}        |
# |2026-06-05 11:06:46.394|{113 Reeves Oval\nChanbury, UT 40179, 0, Katherine Wright, 922-262-0398x5836, Circular Pi Pizzeria, 9.6, [{Peperoni, [🥓 bacon, 🥚 egg]}], 1780628806394}                                                                                                                                                                                        |
# |2026-06-05 11:06:48.398|{246 Ramirez Island Apt. 173\nWrightland, KY 20970, 1, Erin Roth, 671.340.8222x66282, Circular Pi Pizzeria, 45.28, [{Peperoni, [🧀 blue cheese, 🫒 olives]}, {Diavola, []}, {Salami, [🧄 garlic]}, {Peperoni, []}], 1780628808398}                                                                                                               |
# |2026-06-05 11:06:49.4  |{38005 Young Track Apt. 667\nRiverashire, NC 33178, 2, Sandra Hoffman, (863)238-8235, Its-a me! Mario Pizza!, 40.9, [{Diavola, [🍌 banana, 🥚 egg, 🍌 banana]}, {Diavola, [🍌 banana, 🧀 blue cheese]}, {Peperoni, [🫑 green peppers, 🍌 banana, 🐟 tuna]}, {Marinara, [🌶️ hot pepper]}], 1780628809399}                                        |
# |2026-06-05 11:06:51.402|{6306 Rodriguez Loop\nPort Grant, CA 94996, 3, Patricia Deleon, 001-374-979-0049, Its-a me! Mario Pizza!, 10.41, [{Marinara, [🫑 green peppers, 🌶️ hot pepper, 🫑 green peppers]}, {Peperoni, [🫑 green peppers, 🍅 tomato, 🍍 pineapple]}], 1780628811401}                                                                                     |
# |2026-06-05 11:06:52.404|{67042 Melissa Overpass\nWest Johnmouth, HI 35018, 4, Christopher Chang, 286-602-4805, Its-a me! Mario Pizza!, 44.11, [{Peperoni, [🍅 tomato]}, {Margherita, []}], 1780628812403}                                                                                                                                                                |
# +-----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# We can use _dot notation_ to select the field within a `Struct`:

# %%
parsed_df.select("value.cost").show()
# Out:
# 26/06/05 11:24:05 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 3:>                                                          (0 + 1) / 1]
# +-----+
# | cost|
# +-----+
# |18.47|
# |11.26|
# |32.18|
# |16.81|
# | 6.67|
# |29.18|
# |13.28|
# |46.88|
# | 1.42|
# |34.51|
# | 0.29|
# |13.19|
# | 7.28|
# |18.75|
# | 14.4|
# |  9.6|
# |45.28|
# | 40.9|
# |10.41|
# |44.11|
# +-----+
# only showing top 20 rows

# %% [markdown]
# Computing the "total revenue" per shop:

# %%
parsed_df.groupBy("value.shop").sum("value.cost").show(truncate=False)
# Out:
# 26/06/05 11:24:44 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 4:>                                                          (0 + 1) / 1]
# +------------------------------------+-----------------------+
# |shop                                |sum(value.cost AS cost)|
# +------------------------------------+-----------------------+
# |Ill Make You a Pizza You Cant Refuse|154.89000000000001     |
# |Luigis Pizza                        |284.96000000000004     |
# |Mammamia Pizza                      |311.32                 |
# |Its-a me! Mario Pizza!              |264.31                 |
# |Marios Pizza                        |259.25                 |
# |Circular Pi Pizzeria                |248.58999999999997     |
# +------------------------------------+-----------------------+

# %% [markdown]
# > 1. Count the no. of orders by shop.
# > 2. Compute the avg revenue by shop and sort by highest to lowest.

# %%
from pyspark.sql.functions import min, max

# %%
parsed_df.select(min("timestamp"), max("timestamp")).show(truncate=False)
# Out:
# 26/06/05 11:26:01 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# [Stage 7:>                                                          (0 + 1) / 1]
# +-----------------------+-----------------------+
# |min(timestamp)         |max(timestamp)         |
# +-----------------------+-----------------------+
# |2026-06-05 10:55:21.139|2026-06-05 11:14:23.891|
# +-----------------------+-----------------------+

# %% [markdown]
# ## Read and Analyze Kafka stream in "Streaming" Mode
#
# The key idea in Structured Streaming is to treat a live data stream as a table that is being continuously appended. This leads to a new stream processing model that is very similar to a batch processing model. You will express your streaming computation as standard batch-like query as on a static table, and Spark runs it as an incremental query on the *unbounded input table*. Let’s understand this model in more detail.
#
# Consider the input data stream as the “Input Table”. Every data item that is arriving on the stream is like a new row being appended to the Input Table.
#
# ![concept](https://spark.apache.org/docs/latest/img/structured-streaming-stream-as-a-table.png)
#
# A query on the input will generate the “Result Table”. Every trigger interval (say, every 1 second), new rows get appended to the Input Table, which eventually updates the Result Table. Whenever the result table gets updated, we would want to write the changed result rows to an external sink.
#
# ![result table](https://spark.apache.org/docs/latest/img/structured-streaming-model.png)
#
# To illustrate the use of this model, let’s understand the model in context of a word count model. The first lines DataFrame is the input table, and the final wordCounts DataFrame is the result table. Note that the query on streaming lines DataFrame to generate wordCounts is exactly the same as it would be a static DataFrame. However, when this query is started, Spark will continuously check for new data from the socket connection. If there is new data, Spark will run an “incremental” query that combines the previous running counts with the new data to compute updated counts, as shown below.
#
# ![example](https://spark.apache.org/docs/latest/img/structured-streaming-example-model.png)

# %% [markdown]
# Event-time is the time embedded in the data itself. For many applications, you may want to operate on this event-time.
#
# For example, if you want to get the number of events generated by IoT devices every minute, then you probably want to use the time when the data was generated (that is, event-time in the data), rather than the time Spark receives them.
#
# This event-time is very naturally expressed in this model – each event from the devices is a row in the table, and event-time is a column value in the row. This allows window-based aggregations (e.g. number of events every minute) to be just a special type of grouping and aggregation on the event-time column – each time window is a group and each row can belong to multiple windows/groups. Therefore, such event-time-window-based aggregation queries can be defined consistently on both a static dataset (e.g. from collected device events logs) as well as on a data stream, making the life of the user much easier.
#
# Furthermore, this model naturally handles data that has arrived later than expected based on its event-time. Since Spark is updating the Result Table, it has full control over updating old aggregates when there is late data, as well as cleaning up old aggregates to limit the size of intermediate state data.

# %%
pizza_df = spark.readStream.format('kafka')\
    .options(**options)\
    .load()

# %%
pizza_df.isStreaming
# Out:
# True

# %%
pizza_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
parsed_df = pizza_df.select("timestamp", from_json(col("value").cast("string"), order_schema).alias("value"))

# %%
parsed_df.printSchema()
# Out:
# root
#  |-- timestamp: timestamp (nullable = true)
#  |-- value: struct (nullable = true)
#  |    |-- address: string (nullable = true)
#  |    |-- id: integer (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- phoneNumber: string (nullable = true)
#  |    |-- shop: string (nullable = true)
#  |    |-- cost: double (nullable = true)
#  |    |-- pizzas: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- pizzaName: string (nullable = true)
#  |    |    |    |-- additionalToppings: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |-- timestamp: long (nullable = true)

# %%
query = parsed_df \
    .writeStream \
    .format("console") \
    .start()

# query.awaitTermination() # stops the script from exiting. But this is not required in Jupyter because the kernel stays alive. In real Spark applications, you need awaitTermination() to keep the job running.
# query.isActive
# query.recentProgress
# query.stop()
# Out:
# 26/06/05 11:29:36 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-e11c77e0-7c65-4917-8a29-e94e096d86f3. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/06/05 11:29:36 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 26/06/05 11:29:37 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +---------+-----+
# |timestamp|value|
# +---------+-----+
# +---------+-----+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2026-06-05 11:29:...|{53901 Leonard Is...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2026-06-05 11:29:...|{65584 Jones Stre...|
# +--------------------+--------------------+
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2026-06-05 11:29:...|{PSC 1799, Box 68...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2026-06-05 11:29:...|{052 Kylie Extens...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2026-06-05 11:29:...|{779 Brennan Squa...|
# +--------------------+--------------------+

# %%
query.stop()

# %%
query.recentProgress
# Out:
# [{'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:08:40.658Z',
#   'batchId': 0,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'addBatch': 23,
#    'getBatch': 1,
#    'latestOffset': 3254,
#    'queryPlanning': 7,
#    'triggerExecution': 3482,
#    'walCommit': 90},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': None,
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:08:54.147Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:09:04.156Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:09:14.169Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:09:24.179Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:09:34.193Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:09:44.203Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:09:54.217Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:10:04.234Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 12, 'triggerExecution': 12},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:10:14.221Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 55, 'triggerExecution': 55},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:10:24.280Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:10:34.291Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 12, 'triggerExecution': 12},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:10:44.309Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:10:54.314Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:11:04.326Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:11:14.332Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 6, 'triggerExecution': 6},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:11:24.337Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 10, 'triggerExecution': 10},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:11:34.351Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 8, 'triggerExecution': 8},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:11:44.364Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 15, 'triggerExecution': 15},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:11:54.386Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 6, 'triggerExecution': 6},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:12:04.401Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 6, 'triggerExecution': 6},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:12:14.414Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 3, 'triggerExecution': 3},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:12:24.424Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:12:34.438Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 10, 'triggerExecution': 10},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:12:44.460Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 13, 'triggerExecution': 13},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:12:54.474Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 7, 'triggerExecution': 7},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:04.477Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 12, 'triggerExecution': 12},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:14.492Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 16, 'triggerExecution': 16},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:24.497Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 12, 'triggerExecution': 12},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:34.508Z',
#   'batchId': 1,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 8, 'triggerExecution': 8},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 9}},
#     'latestOffset': {'pizza-orders': {'0': 9}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:36.636Z',
#   'batchId': 1,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 52.631578947368425,
#   'processedRowsPerSecond': 0.7757951900698216,
#   'durationMs': {'addBatch': 699,
#    'getBatch': 1,
#    'latestOffset': 2,
#    'queryPlanning': 18,
#    'triggerExecution': 1289,
#    'walCommit': 242},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 9}},
#     'endOffset': {'pizza-orders': {'0': 10}},
#     'latestOffset': {'pizza-orders': {'0': 10}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 52.631578947368425,
#     'processedRowsPerSecond': 0.7757951900698216,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:37.925Z',
#   'batchId': 2,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 0.7757951900698216,
#   'processedRowsPerSecond': 0.8176614881439084,
#   'durationMs': {'addBatch': 609,
#    'getBatch': 0,
#    'latestOffset': 6,
#    'queryPlanning': 6,
#    'triggerExecution': 1223,
#    'walCommit': 224},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 10}},
#     'endOffset': {'pizza-orders': {'0': 11}},
#     'latestOffset': {'pizza-orders': {'0': 11}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 0.7757951900698216,
#     'processedRowsPerSecond': 0.8176614881439084,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:39.635Z',
#   'batchId': 3,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 83.33333333333333,
#   'processedRowsPerSecond': 0.9433962264150942,
#   'durationMs': {'addBatch': 581,
#    'getBatch': 0,
#    'latestOffset': 2,
#    'queryPlanning': 7,
#    'triggerExecution': 1060,
#    'walCommit': 250},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 11}},
#     'endOffset': {'pizza-orders': {'0': 12}},
#     'latestOffset': {'pizza-orders': {'0': 12}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 83.33333333333333,
#     'processedRowsPerSecond': 0.9433962264150942,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:41.642Z',
#   'batchId': 4,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 62.5,
#   'processedRowsPerSecond': 0.8857395925597874,
#   'durationMs': {'addBatch': 583,
#    'getBatch': 0,
#    'latestOffset': 5,
#    'queryPlanning': 6,
#    'triggerExecution': 1129,
#    'walCommit': 267},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 12}},
#     'endOffset': {'pizza-orders': {'0': 13}},
#     'latestOffset': {'pizza-orders': {'0': 13}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 62.5,
#     'processedRowsPerSecond': 0.8857395925597874,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:42.772Z',
#   'batchId': 5,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 0.8849557522123894,
#   'processedRowsPerSecond': 0.9337068160597572,
#   'durationMs': {'addBatch': 590,
#    'getBatch': 0,
#    'latestOffset': 3,
#    'queryPlanning': 5,
#    'triggerExecution': 1071,
#    'walCommit': 234},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 13}},
#     'endOffset': {'pizza-orders': {'0': 14}},
#     'latestOffset': {'pizza-orders': {'0': 14}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 0.8849557522123894,
#     'processedRowsPerSecond': 0.9337068160597572,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:44.655Z',
#   'batchId': 6,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 66.66666666666667,
#   'processedRowsPerSecond': 0.9578544061302682,
#   'durationMs': {'addBatch': 582,
#    'getBatch': 0,
#    'latestOffset': 3,
#    'queryPlanning': 5,
#    'triggerExecution': 1044,
#    'walCommit': 225},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 14}},
#     'endOffset': {'pizza-orders': {'0': 15}},
#     'latestOffset': {'pizza-orders': {'0': 15}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 66.66666666666667,
#     'processedRowsPerSecond': 0.9578544061302682,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:45.700Z',
#   'batchId': 7,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 0.9569377990430623,
#   'processedRowsPerSecond': 0.9416195856873822,
#   'durationMs': {'addBatch': 558,
#    'getBatch': 0,
#    'latestOffset': 5,
#    'queryPlanning': 4,
#    'triggerExecution': 1062,
#    'walCommit': 224},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 15}},
#     'endOffset': {'pizza-orders': {'0': 16}},
#     'latestOffset': {'pizza-orders': {'0': 16}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 0.9569377990430623,
#     'processedRowsPerSecond': 0.9416195856873822,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:46.763Z',
#   'batchId': 8,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 0.9407337723424272,
#   'processedRowsPerSecond': 0.9267840593141798,
#   'durationMs': {'addBatch': 591,
#    'getBatch': 0,
#    'latestOffset': 2,
#    'queryPlanning': 18,
#    'triggerExecution': 1079,
#    'walCommit': 229},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 16}},
#     'endOffset': {'pizza-orders': {'0': 17}},
#     'latestOffset': {'pizza-orders': {'0': 17}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 0.9407337723424272,
#     'processedRowsPerSecond': 0.9267840593141798,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:48.673Z',
#   'batchId': 9,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 55.55555555555556,
#   'processedRowsPerSecond': 0.9469696969696969,
#   'durationMs': {'addBatch': 549,
#    'getBatch': 5,
#    'latestOffset': 5,
#    'queryPlanning': 6,
#    'triggerExecution': 1056,
#    'walCommit': 241},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 17}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 55.55555555555556,
#     'processedRowsPerSecond': 0.9469696969696969,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:13:59.731Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:14:09.737Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:14:19.741Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:14:29.749Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 7, 'triggerExecution': 7},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:14:39.754Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 5, 'triggerExecution': 5},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:14:49.760Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 7, 'triggerExecution': 7},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:14:59.770Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 8, 'triggerExecution': 8},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:15:09.777Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 4, 'triggerExecution': 4},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:15:19.789Z',
#   'batchId': 10,
#   'numInputRows': 0,
#   'inputRowsPerSecond': 0.0,
#   'processedRowsPerSecond': 0.0,
#   'durationMs': {'latestOffset': 2, 'triggerExecution': 2},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 18}},
#     'latestOffset': {'pizza-orders': {'0': 18}},
#     'numInputRows': 0,
#     'inputRowsPerSecond': 0.0,
#     'processedRowsPerSecond': 0.0,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 0}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:15:25.471Z',
#   'batchId': 10,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 52.631578947368425,
#   'processedRowsPerSecond': 0.89126559714795,
#   'durationMs': {'addBatch': 587,
#    'getBatch': 0,
#    'latestOffset': 2,
#    'queryPlanning': 4,
#    'triggerExecution': 1122,
#    'walCommit': 268},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 18}},
#     'endOffset': {'pizza-orders': {'0': 19}},
#     'latestOffset': {'pizza-orders': {'0': 19}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 52.631578947368425,
#     'processedRowsPerSecond': 0.89126559714795,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:15:26.593Z',
#   'batchId': 11,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 0.89126559714795,
#   'processedRowsPerSecond': 1.0141987829614605,
#   'durationMs': {'addBatch': 553,
#    'getBatch': 0,
#    'latestOffset': 12,
#    'queryPlanning': 5,
#    'triggerExecution': 986,
#    'walCommit': 241},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 19}},
#     'endOffset': {'pizza-orders': {'0': 20}},
#     'latestOffset': {'pizza-orders': {'0': 20}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 0.89126559714795,
#     'processedRowsPerSecond': 1.0141987829614605,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:15:28.481Z',
#   'batchId': 12,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 50.0,
#   'processedRowsPerSecond': 1.0471204188481675,
#   'durationMs': {'addBatch': 548,
#    'getBatch': 0,
#    'latestOffset': 8,
#    'queryPlanning': 4,
#    'triggerExecution': 955,
#    'walCommit': 194},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 20}},
#     'endOffset': {'pizza-orders': {'0': 21}},
#     'latestOffset': {'pizza-orders': {'0': 21}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 50.0,
#     'processedRowsPerSecond': 1.0471204188481675,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:15:29.472Z',
#   'batchId': 13,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 55.55555555555556,
#   'processedRowsPerSecond': 0.9442870632672333,
#   'durationMs': {'addBatch': 553,
#    'getBatch': 0,
#    'latestOffset': 6,
#    'queryPlanning': 6,
#    'triggerExecution': 1059,
#    'walCommit': 306},
#   'stateOperators': [],
#   'sources': [{'description': 'KafkaV2[Subscribe[pizza-orders]]',
#     'startOffset': {'pizza-orders': {'0': 21}},
#     'endOffset': {'pizza-orders': {'0': 22}},
#     'latestOffset': {'pizza-orders': {'0': 22}},
#     'numInputRows': 1,
#     'inputRowsPerSecond': 55.55555555555556,
#     'processedRowsPerSecond': 0.9442870632672333,
#     'metrics': {'avgOffsetsBehindLatest': '0.0',
#      'maxOffsetsBehindLatest': '0',
#      'minOffsetsBehindLatest': '0'}}],
#   'sink': {'description': 'org.apache.spark.sql.execution.streaming.ConsoleTable$@6f418af6',
#    'numOutputRows': 1}},
#  {'id': '590d73ca-0eaa-4c3b-a9d7-47794ea5a5cd',
#   'runId': '88fc1108-a1e5-43f6-8593-a3f277ef2afe',
#   'name': None,
#   'timestamp': '2025-03-18T14:15:31.475Z',
#   'batchId': 14,
#   'numInputRows': 1,
#   'inputRowsPerSecond': 66.66666666666667,
#   'processedRowsPerSecond': 0.998003992015968,
#   'durationMs': {'addBatch': 556,
# ...
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{4298 Schroeder C...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{4298 Schroeder C...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{4298 Schroeder C...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0346 Joyce Pine\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0346 Joyce Pine\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0346 Joyce Pine\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0346 Joyce Pine\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# -------------------------------------------
# Batch: 20
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0346 Joyce Pine\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0346 Joyce Pine\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0603 Brandi Path...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0603 Brandi Path...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0603 Brandi Path...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0603 Brandi Path...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0603 Brandi Path...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 21
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{0603 Brandi Path...|
# +--------------------+--------------------+
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{94556 Chaney Cam...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{94556 Chaney Cam...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{94556 Chaney Cam...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{94556 Chaney Cam...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 22
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{94556 Chaney Cam...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{94556 Chaney Cam...|
# +--------------------+--------------------+
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{3903 Jose Fords\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{3903 Jose Fords\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{3903 Jose Fords\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# -------------------------------------------
# Batch: 23
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{3903 Jose Fords\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{3903 Jose Fords\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{3903 Jose Fords\...|
# +--------------------+--------------------+
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# -------------------------------------------
# Batch: 24
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{06867 Sean Sprin...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{06867 Sean Sprin...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{06867 Sean Sprin...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{06867 Sean Sprin...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{06867 Sean Sprin...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{06867 Sean Sprin...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{5781 John Fords\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{5781 John Fords\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{5781 John Fords\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{5781 John Fords\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# -------------------------------------------
# Batch: 25
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{5781 John Fords\...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:15:...|{5781 John Fords\...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{42486 Kelly Traf...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{42486 Kelly Traf...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{42486 Kelly Traf...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{42486 Kelly Traf...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# -------------------------------------------
# Batch: 26
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{42486 Kelly Traf...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{42486 Kelly Traf...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{37881 Clayton Co...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{37881 Clayton Co...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{37881 Clayton Co...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{37881 Clayton Co...|
# +--------------------+--------------------+
#
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{37881 Clayton Co...|
# +--------------------+--------------------+
#
# -------------------------------------------
# Batch: 27
# -------------------------------------------
# +--------------------+--------------------+
# |           timestamp|               value|
# +--------------------+--------------------+
# |2025-03-18 22:16:...|{37881 Clayton Co...|
# +--------------------+--------------------+

# %% [markdown]
# ### In the next few cells, we will provide a complete example of counting the number of orders per pizza shop, as the orders stream in.

# %%
# First check if any streams are active
spark.streams.active

# %%
# If there are any active streams, stop them
for q in spark.streams.active:
    print(f"Stopping query: {q.name}")
    q.stop()
# Out:
# Stopping query: None

# %%
# Complete example with counting
pizza_df = spark.readStream.format('kafka')\
    .options(**options)\
    .load()

parsed_df = pizza_df.select("timestamp", from_json(col("value").cast("string"), order_schema).alias("value")) #.groupBy("value.shop").count()

shop_counts = parsed_df.groupBy("value.shop").count()

# outputMode("complete") rewrites all aggregated results every trigger — good for full snapshots.
# outputMode("update") - only updated rows are written
query = shop_counts \
    .writeStream \
    .outputMode("complete") \
    .format("console") \
    .start()

query.awaitTermination()
# Out:
# 26/06/05 11:36:22 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-f9f89d1e-37d8-4308-b42c-c111a066e889. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/06/05 11:36:22 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 26/06/05 11:36:22 WARN AdminClientConfig: These configurations '[key.deserializer, value.deserializer, enable.auto.commit, max.poll.records, auto.offset.reset]' were supplied but are not used yet.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+-----+
# |shop|count|
# +----+-----+
# +----+-----+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------------------+-----+
# |                shop|count|
# +--------------------+-----+
# |        Luigis Pizza|    2|
# |Its-a me! Mario P...|    2|
# |Circular Pi Pizzeria|    1|
# +--------------------+-----+
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +--------------------+-----+
# |                shop|count|
# +--------------------+-----+
# |        Luigis Pizza|    2|
# |      Mammamia Pizza|    1|
# |Its-a me! Mario P...|    2|
# |Circular Pi Pizzeria|    1|
# +--------------------+-----+
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------------------+-----+
# |                shop|count|
# +--------------------+-----+
# |        Luigis Pizza|    3|
# |      Mammamia Pizza|    1|
# |Its-a me! Mario P...|    2|
# |        Marios Pizza|    3|
# |Circular Pi Pizzeria|    1|
# +--------------------+-----+
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +--------------------+-----+
# |                shop|count|
# +--------------------+-----+
# |        Luigis Pizza|    3|
# |      Mammamia Pizza|    2|
# |Its-a me! Mario P...|    2|
# |        Marios Pizza|    3|
# |Circular Pi Pizzeria|    1|
# +--------------------+-----+
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +--------------------+-----+
# |                shop|count|
# +--------------------+-----+
# |        Luigis Pizza|    3|
# |      Mammamia Pizza|    5|
# |Its-a me! Mario P...|    2|
# |        Marios Pizza|    3|
# |Circular Pi Pizzeria|    2|
# +--------------------+-----+
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/clement/miniconda3/envs/kafka/lib/python3.11/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/clement/miniconda3/envs/kafka/lib/python3.11/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#                           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/clement/miniconda3/envs/kafka/lib/python3.11/socket.py", line 718, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 18
#      14     .outputMode("complete") \
#      15     .format("console") \
#      16     .start()
#      17
# ---> 18 query.awaitTermination()
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/pyspark/sql/streaming/query.py:221, in StreamingQuery.awaitTermination(self, timeout)
#     219     return self._jsq.awaitTermination(int(timeout * 1000))
#     220 else:
# --> 221     return self._jsq.awaitTermination()
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/miniconda3/envs/kafka/lib/python3.11/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File ~/miniconda3/envs/kafka/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
query.stop()

# %% [markdown]
# You have come to the end of this exercise.
#
# To delete the Kafka topic `pizza-orders`, use the command below in your terminal:
#
# `./kafka-topics.sh --delete --topic pizza-orders --bootstrap-server localhost:9092`
#
# To exit Kafka in your terminal, type `exit`.
